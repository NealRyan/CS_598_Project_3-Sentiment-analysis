# %% [markdown]
# # Project 3: CS 598 Practical Statistical Learning, Fall 2023
#
# ## Movie Review Sentiment Analysis
#
# #### Team Members and Responsibilities
# * **Kurt Tuohy** *(ktuohy):* contraction expansion, token t-test, token exploration
# * **Neal Ryan** *(nealpr2):* notebook configuration, initial tokenization, lasso token regularization
# * **Alelign Faris** *(faris2):* mymain.py

# %% [markdown]
# Our approach is based on Campuswire post [628](https://campuswire.com/c/G06C55090/feed/628).

# %% [markdown]
# ## 1) Import libraries and data

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

SEED = 4031
np.random.seed(SEED)

# %%
# Pull in datasets
train_datasets = []
test_datasets = []
test_ys = []

num_folds = 5

for fold in range(num_folds):
    folder = f"Data/split_{fold+1}/"
    train_datasets.append(pd.read_csv(folder + "train.tsv", sep="\t"))
    test_datasets.append(pd.read_csv(folder + "test.tsv", sep="\t"))
    test_ys.append(pd.read_csv(folder + "test_y.tsv", sep="\t"))

# %% [markdown]
# ## 2) Construct vocabulary

# %%
# Use all training data to construct vocabulary.

all_train = pd.concat(train_datasets, axis=0, ignore_index=True)
all_train.drop(columns=["id"], inplace=True)
all_train
# Out:
#         sentiment                                             review
# 0               1  Naturally in a film who's main themes are of m...
# 1               0  Afraid of the Dark left me with the impression...
# 2               0  This has to be one of the biggest misfires eve...
# 3               0  This is one of those movies I watched, and won...
# 4               0  This movie was dreadful. Biblically very inacc...
# ...           ...                                                ...
# 124995          0  I am a student of film, and have been for seve...
# 124996          0  It seems like more consideration has gone into...
# 124997          0  I don't believe they made this film. Completel...
# 124998          0  This 30 minute documentary Buñuel made in the ...
# 124999          1  I saw this movie as a child and it broke my he...
#
# [125000 rows x 2 columns]

# %% [markdown]
# ### Preprocess text

# %%
def expand_contractions(reviews):
    
    """
    Routine to expand English contractions, like "isn't" --> "is not".
    This is because "isn't good" and "wasn't good" will both expand to produce the bi-gram "not good".
    The pooled phrase should have more predictive power than the original two phrases.
    """

    # Dictionary of English contractions. Taken from StackOverflow post, which borrowed it from Wikipedia:
    # https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python

    contractions = { 
        "\\bain't\\b": "am not",
        "\\baren't\\b": "are not",
        "\\bcan't\\b": "cannot",
        "\\bcan't've\\b": "cannot have",
        "\\b'cause\\b": "because",
        "\\bcould've\\b": "could have",
        "\\bcouldn't\\b": "could not",
        "\\bcouldn't've\\b": "could not have",
        "\\bdidn't\\b": "did not",
        "\\bdoesn't\\b": "does not",
        "\\bdon't\\b": "do not",
        "\\bhadn't\\b": "had not",
        "\\bhadn't've\\b": "had not have",
        "\\bhasn't\\b": "has not",
        "\\bhaven't\\b": "have not",
        "\\bhe'd\\b": "he would",
        "\\bhe'd've\\b": "he would have",
        "\\bhe'll\\b": "he will",
        "\\bhe'll've\\b": "he will have",
        "\\bhe's\\b": "he is",
        "\\bhow'd\\b": "how did",
        "\\bhow'd'y\\b": "how do you",
        "\\bhow'll\\b": "how will",
        "\\bhow's\\b": "how is",
        "\\bi'd\\b": "i would",
        "\\bi'd've\\b": "i would have",
        "\\bi'll\\b": "i will",
        "\\bi'll've\\b": "i will have",
        "\\bi'm\\b": "i am",
        "\\bi've\\b": "i have",
        "\\bisn't\\b": "is not",
        "\\bit'd\\b": "it would",
        "\\bit'd've\\b": "it would have",
        "\\bit'll\\b": "it will",
        "\\bit'll've\\b": "it will have",
        "\\bit's\\b": "it is",
        "\\blet's\\b": "let us",
        "\\bma'am\\b": "madam",
        "\\bmayn't\\b": "may not",
        "\\bmight've\\b": "might have",
        "\\bmightn't\\b": "might not",
        "\\bmightn't've\\b": "might not have",
        "\\bmust've\\b": "must have",
        "\\bmustn't\\b": "must not",
        "\\bmustn't've\\b": "must not have",
        "\\bneedn't\\b": "need not",
        "\\bneedn't've\\b": "need not have",
        "\\bo'clock\\b": "of the clock",
        "\\boughtn't\\b": "ought not",
        "\\boughtn't've\\b": "ought not have",
        "\\bshan't\\b": "shall not",
        "\\bsha'n't\\b": "shall not",
        "\\bshan't've\\b": "shall not have",
        "\\bshe'd\\b": "she would",
        "\\bshe'd've\\b": "she would have",
        "\\bshe'll\\b": "she will",
        "\\bshe'll've\\b": "she will have",
        "\\bshe's\\b": "she is",
        "\\bshould've\\b": "should have",
        "\\bshouldn't\\b": "should not",
        "\\bshouldn't've\\b": "should not have",
        "\\bso've\\b": "so have",
        "\\bso's\\b": "so is",
        "\\bthat'd\\b": "that would",
        "\\bthat'd've\\b": "that would have",
        "\\bthat's\\b": "that is",
        "\\bthere'd\\b": "there would",
        "\\bthere'd've\\b": "there would have",
        "\\bthere's\\b": "there is",
        "\\bthey'd\\b": "they would",
        "\\bthey'd've\\b": "they would have",
        "\\bthey'll\\b": "they will",
        "\\bthey'll've\\b": "they will have",
        "\\bthey're\\b": "they are",
        "\\bthey've\\b": "they have",
        "\\bto've\\b": "to have",
        "\\bwasn't\\b": "was not",
        "\\bwe'd\\b": "we would",
        "\\bwe'd've\\b": "we would have",
        "\\bwe'll\\b": "we will",
        "\\bwe'll've\\b": "we will have",
        "\\bwe're\\b": "we are",
        "\\bwe've\\b": "we have",
        "\\bweren't\\b": "were not",
        "\\bwhat'll\\b": "what will",
        "\\bwhat'll've\\b": "what will have",
        "\\bwhat're\\b": "what are",
        "\\bwhat's\\b": "what is",
        "\\bwhat've\\b": "what have",
        "\\bwhen's\\b": "when is",
        "\\bwhen've\\b": "when have",
        "\\bwhere'd\\b": "where did",
        "\\bwhere's\\b": "where is",
        "\\bwhere've\\b": "where have",
        "\\bwho'll\\b": "who will",
        "\\bwho'll've\\b": "who will have",
        "\\bwho's\\b": "who is",
        "\\bwho've\\b": "who have",
        "\\bwhy's\\b": "why is",
        "\\bwhy've\\b": "why have",
        "\\bwill've\\b": "will have",
        "\\bwon't\\b": "will not",
        "\\bwon't've\\b": "will not have",
        "\\bwould've\\b": "would have",
        "\\bwouldn't\\b": "would not",
        "\\bwouldn't've\\b": "would not have",
        "\\by'all\\b": "you all",
        "\\by'all'd\\b": "you all would",
        "\\by'all'd've\\b": "you all would have",
        "\\by'all're\\b": "you all are",
        "\\by'all've\\b": "you all have",
        "\\byou'd\\b": "you would",
        "\\byou'd've\\b": "you would have",
        "\\byou'll\\b": "you will",
        "\\byou'll've\\b": "you will have",
        "\\byou're\\b": "you are",
        "\\byou've\\b": "you have"
    }
    
    # Replace all contractions in all reviews.
    for contraction in contractions:
        reviews = reviews.str.replace(contraction, contractions[contraction], regex=True)
        
    return reviews

# %%
# Preprocessing pipeline: strip out HTML, convert to lowercase, and expand English contractions.

def preprocess_reviews(reviews):
    """
    Routine to preprocess text: strip out HTML, convert to lowercase, and expand English contractions.
    """

    # Remove HTML tags
    reviews = reviews.str.replace('<.*?>', ' ', regex=True)
    # Convert to lowercase
    reviews = reviews.str.lower()
    # Expand English contractions
    reviews = expand_contractions(reviews)
    
    return reviews

# %%
# Custom stopword list from Campuswire post 626: https://campuswire.com/c/G06C55090/feed/626

stopwords = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "their", "they", "his", \
             "her", "she", "he", "a", "an", "and", "is", "was", "are", "were", "him", "himself", "has", "have", "it", "its", \
             "the", "us"]

# %%
# Preprocess all training text
all_train["review"] = preprocess_reviews(all_train["review"])

# %%
# Vectorize the reviews

vectorizer = CountVectorizer(
    stop_words=stopwords,             # Remove stop words
    ngram_range=(1, 4),               # Use 1- to 4-grams
    min_df=0.001,                     # Minimum term frequency
    max_df=0.5,                       # Maximum document frequency
    token_pattern=r"\b[\w+\|']+\b"    # Use word tokenizer, but don't split on apostrophes
)

dtm_train = vectorizer.fit_transform(all_train["review"])

# %%
# View the number of ngrams
feature_ngrams = vectorizer.get_feature_names_out()
feature_ngrams.shape
# Out:
# (31701,)

# %% [markdown]
# ### Use t-test to identify strongest 2000 positive and negative terms

# %%
# Try t-test to identify terms that are strongly associated with either positive or negative reviews.

# Separate positive and negative reviews
dtm_pos = dtm_train[all_train.sentiment == 1, :]
dtm_neg = dtm_train[all_train.sentiment == 0, :]

# %%
# Count positive and negative reviews
dtm_pos_count = dtm_pos.shape[0]
dtm_neg_count = dtm_neg.shape[0]

# %%
# Define variables to hold means and variances of each ngram in positive & negative reviews
dtm_pos_means = np.empty(feature_ngrams.shape[0])
dtm_pos_vars = np.empty(feature_ngrams.shape[0])

dtm_neg_means = np.empty(feature_ngrams.shape[0])
dtm_neg_vars = np.empty(feature_ngrams.shape[0])

# %%
# Compute ngram means and sample variances using dense matrices instead of sparse matrices, one column at a time.
# This is because computing variance of sparse matrices is reported to have numerical instability.
# Use one column at a time to avoid consuming too much memory.
# Approach taken from StackOverflow post:
# https://stackoverflow.com/questions/12169611/how-do-i-compute-the-variance-of-a-column-of-a-sparse-matrix-in-scipy

for col in range(feature_ngrams.shape[0]):
    pos_col_array = dtm_pos[:, col].toarray()
    dtm_pos_means[col] = np.mean(pos_col_array)
    dtm_pos_vars[col] = np.var(pos_col_array, ddof=1)
    
    neg_col_array = dtm_neg[:, col].toarray()
    dtm_neg_means[col] = np.mean(neg_col_array)
    dtm_neg_vars[col] = np.var(neg_col_array, ddof=1)

# %%
# For each ngram, compute t-statistic for two independent samples.
# Hmmm...they're not independent, but we can't really pool the variance...

t_statistics = (dtm_pos_means - dtm_neg_means) / np.sqrt((dtm_pos_vars/dtm_pos_count) + (dtm_neg_vars/dtm_neg_count))

# %%
# Link ngrams to their t-statistics
feature_statistic_df = pd.DataFrame({"feature": feature_ngrams.tolist(), "statistic": t_statistics.tolist()})

# %%
# Look at top 50 positive words
feature_statistic_df.sort_values(by="statistic", ascending=False).iloc[0:50, :]
# Out:
#                   feature  statistic
# 10874               great  73.982716
# 8232            excellent  58.862798
# 31186           wonderful  53.246837
# 3247                 best  53.155283
# 17806             of best  51.324386
# 19152         one of best  48.932390
# 14764                love  43.829750
# 20103             perfect  41.751995
# 1406              amazing  40.271278
# 2936            beautiful  39.589658
# 14801               loved  39.514111
# 29870                well  38.451604
# 24828              superb  38.215725
# 3739            brilliant  38.141745
# 8679             favorite  37.800354
# 14257                life  36.662636
# 11540              highly  35.418083
# 16536            must see  35.275773
# 1224                 also  34.927260
# 29228                very  33.866042
# 19149              one of  33.427117
# 8586            fantastic  33.146335
# 2949          beautifully  33.106315
# 20115         performance  33.104688
# 3618                 both  32.063273
# 29343           very well  31.721133
# 28321               today  31.350023
# 7804              enjoyed  30.820844
# 20128        performances  30.688425
# 1307               always  30.646900
# 29947          well worth  30.359774
# 301                  8 10  29.618769
# 31596               years  29.375083
# 19721         outstanding  29.215841
# 11542    highly recommend  29.086497
# 26557          this great  29.061440
# 28487            touching  28.927331
# 24                  10 10  28.664055
# 31277               world  28.650884
# 31652               young  28.566383
# 24610              strong  28.536829
# 20657            powerful  28.514348
# 31194         wonderfully  28.452246
# 29877             well as  28.417276
# 6334           definitely  28.268586
# 20112           perfectly  28.164201
# 2075              as well  28.115403
# 11546  highly recommended  27.925894
# 289                  7 10  27.507769
# 2076           as well as  27.434764

# %%
# Look at bottom 50 words (most negative)
feature_statistic_df.sort_values(by="statistic").iloc[0:50, :]
# Out:
#               feature  statistic
# 2537              bad -94.755462
# 31315           worst -84.764359
# 29641           waste -68.997657
# 2465            awful -64.850629
# 17113        not even -58.121304
# 25264        terrible -57.600314
# 31306           worse -53.553785
# 3598           boring -52.661545
# 24670          stupid -50.814659
# 16835              no -50.695585
# 17540         nothing -50.552694
# 29644        waste of -50.402360
# 18668        of worst -49.201362
# 11716        horrible -48.510445
# 20542            poor -48.450687
# 15622         minutes -47.237653
# 7992             even -45.669468
# 13504            just -45.419072
# 23640          so bad -44.844958
# 5936             crap -44.480812
# 19199    one of worst -43.562671
# 20548          poorly -43.186878
# 24867        supposed -43.143946
# 567            acting -43.045135
# 2169           at all -42.293576
# 24868     supposed to -41.246715
# 21954      ridiculous -41.040249
# 20425            plot -40.879246
# 5783            could -40.671791
# 30629             why -40.617536
# 6864               do -40.385450
# 22627          script -40.084532
# 6898           do not -39.541573
# 13944            lame -39.516830
# 29647   waste of time -39.067059
# 2422            avoid -38.959725
# 31328     worst movie -38.241648
# 29657          wasted -37.762129
# 17497       not waste -37.274232
# 1510         annoying -37.113367
# 7359             dull -36.605027
# 29649      waste time -36.465669
# 6982     do not waste -35.880702
# 18746              oh -35.761045
# 20501       pointless -35.559514
# 15740           money -35.548515
# 15481            mess -35.506881
# 4943            cheap -35.372461
# 14033       laughable -34.981153
# 24869  supposed to be -34.978736

# %%
# Keep the top 2000 terms by magnitude of t-statistic

n_terms = 2000

feature_statistic_df["abs_statistic"] = abs(feature_statistic_df["statistic"])

top_features = feature_statistic_df.sort_values(by="abs_statistic", ascending=False).iloc[:n_terms, 0]
top_features
# Out:
# 2537                     bad
# 31315                  worst
# 10874                  great
# 29641                  waste
# 2465                   awful
#                 ...
# 24033                sounded
# 16860              no excuse
# 26662    this movie horrible
# 24173                spot on
# 17214            not in good
# Name: feature, Length: 2000, dtype: object

# %%
# Add any terms that only appeared in positive reviews or only in negative reviews.
only_positive = feature_ngrams[np.logical_and((dtm_pos_means > 0), (dtm_neg_means == 0))]
only_negative = feature_ngrams[np.logical_and((dtm_pos_means == 0), (dtm_neg_means > 0))]
only_negative
# Out:
# array(['avoid like', 'bad as this', 'bad music', 'could not save',
#        'crap like this', 'do not waste money', 'easily worst', 'gave 2',
#        'how not to make', 'instead of 1', 'manos', 'not funny not',
#        'not waste money on', 'not waste time or', 'this by far worst',
#        'this drivel', 'this dull', 'this junk', 'this lame',
#        'this piece of garbage', 'this rubbish', 'this stinker',
#        'this tripe', 'this turkey', 'this waste', 'this waste of',
#        'waste time or', 'waste time or money', 'waste time with this',
#        'worst movie ever made', 'worst movies ever seen'], dtype=object)

# %%
top_features_list = list(set(top_features.tolist() + only_positive.tolist() + only_negative.tolist()))
top_features_list
# Out:
# ['not funny not',
#  'james',
#  'extraordinary',
#  'very touching',
#  'how bad this movie',
#  'waste of film',
#  'very believable',
#  'come up',
#  'nonsense',
#  'problem with',
#  'kills',
#  'going',
#  'total waste of',
#  'eerie',
#  'dreams',
#  'very funny',
#  'each of',
#  'really',
#  'kind of',
#  'disjointed',
#  'money on',
#  'ever seen',
#  'paint dry',
#  'easy',
#  'bad good',
#  'not even',
#  'allows',
#  'manos',
#  'to sit through',
#  'not very',
#  'joy to',
#  'young man',
#  'no excuse',
#  'really really',
#  'exquisite',
#  'complete waste of time',
#  'explores',
#  'in lives',
#  'exceptional',
#  'hours of',
#  'this trash',
#  'truly awful',
#  'very poorly',
#  'ruined',
#  'supporting cast',
#  'apparent reason',
#  'fresh',
#  'ways',
#  'neither',
#  'bad bad',
#  'am not',
#  'some kind',
#  'black white',
#  'refreshing',
#  'worst acting',
#  'first saw this movie',
#  'sounded',
#  'dramas',
#  'good idea',
#  'thoroughly enjoyed',
#  'not make sense',
#  'learns',
#  'father',
#  'sitting through',
#  'become',
#  'love to',
#  'to see again',
#  'instead',
#  'wanted to like this',
#  'thanks',
#  'very real',
#  'avoid like',
#  'definitely',
#  'not recommend this',
#  'ages',
#  'for no',
#  'wonderful',
#  'redeeming qualities',
#  'bad in',
#  'makes no',
#  'little film',
#  'this garbage',
#  'innocent',
#  'weak',
#  'dvd',
#  'apparently',
#  'story about',
#  'brought to',
#  'stock footage',
#  'not waste',
#  'only saving',
#  'how not to',
#  'least',
#  'hard to be',
#  'great to see',
#  'no apparent reason',
#  'did great job',
#  'crap',
#  'whole thing',
#  'decided',
#  'cheap',
#  'project',
#  'will always',
#  'beautiful',
#  'abomination',
#  'just do not',
#  'point',
#  'absolutely loved',
#  'sometimes',
#  'sat',
#  '30',
#  'far too',
#  'can relate',
#  'then',
#  'only positive',
#  'walked',
#  'film for',
#  'shows',
#  'what waste of',
#  'acting bad',
#  'follows',
#  'completely',
#  'halfway',
#  'along with',
#  'whatsoever',
#  'could made',
#  'great performances',
#  'for no reason',
#  'tremendous',
#  'disappointed',
#  'would recommend',
#  'score',
#  'cgi',
#  'of all time',
#  'not perfect',
#  'below average',
#  'favorites',
#  'can relate to',
#  'highly recommend',
#  'just bad',
#  'great acting',
#  'what makes this',
#  'movie 2',
#  'provides',
#  'twists',
#  'theater 3000',
#  'job',
#  'history',
#  'would love',
#  'unless',
#  'affection',
#  'real',
#  'uninspired',
#  'total waste',
#  'if want to',
#  'tale',
#  'pile of',
#  'movie ever',
#  'watch again',
#  'best',
#  'adds',
#  'on on',
#  'not good',
#  'only good',
#  'bottom of',
#  'performance',
#  'loneliness',
#  'at best',
#  'blood',
#  'insult',
#  'also great',
#  'excellent performances',
#  'oh',
#  'sees',
#  'as bad',
#  'cover',
#  'for those',
#  'makers',
#  'fabulous',
#  'terribly',
#  'excuse',
#  'if not seen',
#  'nicely',
#  '3 10',
#  'plan 9 from outer',
#  'feelings',
#  'movie ever seen',
#  'sharp',
#  'please do',
#  'growing',
#  'hackneyed',
#  'remotely',
#  'as worst',
#  'please do not',
#  'portrait',
#  'not miss',
#  'made',
#  'if director',
#  'helps',
#  '10 minutes',
#  'problem',
#  'unrealistic',
#  'funny or',
#  'there nothing',
#  'steals',
#  'special effects',
#  'unlike',
#  'one of best of',
#  'where to begin',
#  'animation',
#  'reality',
#  'pretty bad',
#  'one of favorite',
#  'not care',
#  'writers',
#  'something better',
#  'lack of',
#  'sake',
#  'would love to',
#  'this movie bad',
#  'at same',
#  'worst movies ever seen',
#  'season',
#  'anything to',
#  'basically',
#  'low',
#  'very moving',
#  'could been good',
#  'well worth',
#  'could not save',
#  'tragedy',
#  'bad acting',
#  'time on',
#  'stupid movie',
#  'sweet',
#  'simply not',
#  'one of greatest',
#  'so poorly',
#  'visual',
#  'not interesting',
#  'of bad',
#  'laughable',
#  'like',
#  'piece of crap',
#  'piece of garbage',
#  'minutes into',
#  'role of',
#  'cried',
#  'reveals',
#  'one of most',
#  '3000',
#  'idiots',
#  'life of',
#  'even bother',
#  'good as',
#  'very well',
#  'not enough to',
#  'from outer space',
#  'stick',
#  'only',
#  'so bad',
#  'wanted to',
#  'other than',
#  'just boring',
#  'no real',
#  'come up with',
#  'played by',
#  'this wonderful',
#  'nevertheless',
#  'obvious',
#  'ugly',
#  'do not believe',
#  'then there',
#  'not waste money on',
#  'ludicrous',
#  'available on',
#  'notch',
#  'avoid this',
#  'do not recommend',
#  'adds to',
#  'begin with',
#  'excellent as',
#  'bad films',
#  'am sorry',
#  'supporting',
#  'makes this',
#  'of trash',
#  'feel good',
#  'below',
#  'years',
#  'looks like',
#  'terrible script',
#  'waste of',
#  'very poor',
#  'boring film',
#  'am afraid',
#  'avoid this movie',
#  'lackluster',
#  '1 out of 10',
#  'name',
#  'could been so',
#  'future',
#  'explanation',
#  'meaningless',
#  'just does',
#  'insipid',
#  'wreck',
#  'oscar',
#  'rip off of',
#  'annoying',
#  '7 out of',
#  'impressed',
#  'mst3k',
#  'embarrassment',
#  'failed',
#  'friendship',
#  'watching',
#  'solid',
#  'about as',
#  'on edge',
#  'home',
#  'great',
#  'some of best',
#  'ashamed',
#  'one of all',
#  'oh god',
#  'one of all time',
#  'how not to make',
#  'just does not work',
#  'ugh',
#  'suck',
#  'bad writing',
#  'great to',
#  'garbage',
#  'just not',
#  '7 10',
#  'bunch of',
#  'fascinating',
#  'bad this',
#  'only good thing about',
#  'see',
#  'not enough',
#  'embarrassed',
#  'excuse for',
#  'horrible',
#  'walked out',
#  'recommend to',
#  'dreck',
#  'this dull',
#  'uninteresting',
#  'biggest problem',
#  'pathetic',
#  'shots',
#  'new',
#  'no idea',
#  'favorite',
#  'believable',
#  'watching this movie',
#  'something',
#  'no sense at all',
#  'easy to',
#  'unfortunately this',
#  'understated',
#  'roles',
#  'pretentious',
#  'yawn',
#  'existent',
#  'not work',
#  'did not work',
#  'best performance',
#  'rented',
#  '2 out of',
#  'how bad this',
#  'am',
#  'fails to',
#  'movie do',
#  'do not rent',
#  '9 from',
#  'alright',
#  'this movie horrible',
#  'spent',
#  'bit',
#  'journey',
#  'cannot even',
#  'not waste money',
#  'could not',
#  'attempts at',
#  'awfulness',
#  'gorgeous',
#  'at all costs',
#  'barely',
#  'movie so',
#  'bad acting bad',
#  'no suspense',
#  'wasting',
#  'this supposed',
#  'could not even',
#  'bad music',
#  'dull',
#  'era',
#  'this poor',
#  'but this',
#  'true to',
#  'portrayal',
#  'do',
#  'saw this film',
#  'to do with',
#  'complex',
#  'give 7',
#  'only good thing',
#  'film so bad',
#  'lazy',
#  'intensity',
#  'out of',
#  'very strong',
#  'clichés',
#  'abysmal',
#  'when first',
#  'endless',
#  'amateur',
#  'unfolds',
#  'of favorites',
#  'too',
#  'so boring',
#  'of finest',
#  'shines',
#  'day',
#  'also very',
#  'quiet',
#  'moving',
#  'nothing happens',
#  '5 minutes',
#  'story told',
#  'if going to',
#  '3 out of 10',
#  'on this',
#  'trying to be',
#  'badly acted',
#  'thanks to',
#  'for free',
#  'yourself favor',
#  'just terrible',
#  'satisfying',
#  'with great',
#  'money on this',
#  'do not waste',
#  'brilliant as',
#  'sit',
#  'of young',
#  'famous',
#  'john',
#  'this great',
#  'this rubbish',
#  'love this film',
#  'why did',
#  'appreciated',
#  'lacked',
#  'premise',
#  'so',
#  'very entertaining',
#  'truly',
#  'worst ever seen',
#  'not scary',
#  'will love',
#  'continuity',
#  'budget',
#  'not funny',
#  'poor acting',
#  'one of funniest',
#  'recommended',
#  'simplicity',
#  'out',
#  'success',
#  'incompetent',
#  'this excellent',
#  'of fun',
#  'sorry but',
#  'did not care',
#  'disappointment',
#  'sense of',
#  'rest',
#  'not waste time with',
#  'give',
#  'excellently',
#  'sucks',
#  'hour',
#  'first off',
#  'utterly',
#  'of funniest',
#  'too many',
#  'trying to',
#  'downhill',
#  'any of',
#  'this piece of',
#  'bin',
#  'on this one',
#  'been better',
#  'around in',
#  'horrible acting',
#  'joy',
#  '3 out',
#  'favorite movie',
#  'thinking',
#  'time on this',
#  'unless want to',
#  'courage',
#  'worst movies ever',
#  'cash in',
#  'emotional',
#  'fell asleep',
#  'video',
#  '2 out',
#  'by',
#  'this movie great',
#  'unexpected',
#  'bottom',
#  'tense',
#  'in own',
#  'bothered',
#  'mean',
#  'awful movie',
#  'see again',
#  'may not be',
#  'unimaginative',
#  'of seat',
#  'music by',
#  'no wonder',
#  'god',
#  'rubbish',
#  'most boring',
#  'musical',
#  'boll',
#  'five minutes',
#  'worst film ever seen',
#  'inaccurate',
#  'familiar',
#  'everyday',
#  'will never get back',
#  'stands',
#  'seemed to',
#  'dumbest',
#  'mature',
#  'performances',
#  'matthau',
#  'running',
#  'cast',
#  'film noir',
#  'does not even',
#  'none of',
#  'music',
#  'movies ever seen',
#  'movie not worth',
#  'society',
#  'do yourself',
#  'childhood',
#  'did this',
#  'could',
#  'genuine',
#  'lacks',
#  'times',
#  'everyone should',
#  'as good as',
#  'fine',
#  'entertaining',
#  'bad movie',
#  'just did',
#  'nothing else',
#  'not to be missed',
#  'surprising',
#  'poorly done',
#  'explain',
#  'lovable',
#  'takes',
#  'if had',
#  'worst movie ever',
#  'ed wood',
#  'piece of trash',
#  'raw',
#  'horror',
#  'skip this one',
#  'actors',
#  'minute',
#  'achievement',
#  'of worst movies ever',
#  'highly',
#  'on edge of seat',
#  'finds',
#  'acting awful',
#  'laugh at',
#  'poorly acted',
#  'that bad',
#  'bad that',
#  'as if',
#  'as always',
#  'nominated',
#  'mildly',
#  'world war',
#  'bad',
#  'much better',
#  'on cover',
#  'cannot believe',
#  'most annoying',
#  'this disaster',
#  'classic',
#  'plain',
#  'god awful',
#  'no chemistry',
#  'flawless',
#  'hours',
#  'this worst movie',
#  'yeah',
#  'stupidity',
#  'wasted',
#  'delight',
#  'going to',
#  'should be ashamed',
#  'great film',
#  'what point',
#  'not save',
#  'fake',
#  'with no',
#  'screaming',
#  'by far worst',
#  'waste money',
#  'without any',
#  'bit too',
#  'walking around',
#  'decent',
#  '8 10',
#  'clichéd',
#  'job of',
#  'wife',
#  '1 out of',
#  'very disappointing',
#  'sub par',
#  'for anyone who',
#  'very boring',
#  'be ashamed',
#  'just',
#  'just plain',
#  'waste of money',
#  'lack',
#  'stock',
#  'minutes of',
#  'same time',
#  'no reason',
#  'edge',
#  '8 out of',
#  'in love',
#  'to be comedy',
#  'to be missed',
#  'to recommend',
#  'definitely worth',
#  'does great',
#  'imdb',
#  'waste time',
#  'not seen',
#  'bore',
#  'lovely',
#  'call that',
#  'this movie terrible',
#  'not be disappointed',
#  'low budget',
#  'stay away',
#  'rare',
#  'ensemble',
#  'zombies',
#  'awful this',
#  'bad as this',
#  'movie had',
#  'in this movie',
#  'worst movie',
#  'will',
#  'why do',
#  'hooked',
#  'unusual',
#  'supposed to be',
#  'fast paced',
#  'still',
#  'sit through',
#  'but unfortunately',
#  'for all',
#  'tale of',
#  'f',
#  'of junk',
#  'superbly',
#  'about this',
#  'blend of',
#  'bad as',
#  'stewart',
#  'no point',
#  '15 minutes',
#  'pile',
#  '4 out',
#  'monster',
#  'best performances',
#  'useless',
#  'insult to',
#  'want to',
#  'perfect for',
#  'wonder',
#  'of worst films ever',
#  'thumbs up',
#  'rewarding',
#  'not even get',
#  'worst film ever',
#  'to cash',
#  'too bad',
#  'horror movie',
#  'to be funny',
#  'minutes of life',
#  'poignant',
#  'camera',
#  'would been',
#  'otherwise',
#  'enjoyed this movie',
#  'comedies',
#  'quite',
#  'turd',
#  'repetitive',
#  'this awful',
#  'movie 1',
#  'at all',
#  'b',
#  'very very bad',
#  'killing',
#  'worst movie of',
#  'want to see',
#  'of best films',
#  'that would',
#  'this great movie',
#  'crap like this',
#  'magnificent',
#  'writing',
#  'did not even',
#  'looked',
#  'mean come on',
#  'those who',
#  'edge of',
#  'not buy',
#  'illogical',
#  'this movie had',
#  'producers',
#  'bother',
#  'love',
#  'sensitive',
#  'tries to be',
#  'unless want',
#  'there',
#  'filmmakers',
#  'darker',
#  'this piece of crap',
#  'not make',
#  'this waste',
#  'heartwarming',
#  'bad really',
#  'money to',
#  'like plague',
#  'warned',
#  'movies',
#  'of time',
#  'nothing more',
#  'thing',
#  'terrible film',
#  'this pile',
#  'script',
#  'no sense',
#  'dialog',
#  'make any',
#  'for no apparent',
#  'hype',
#  'enough to',
#  'not waste time or',
#  '10 out of',
#  'do not watch this',
#  'power of',
#  'worst films ever',
#  'in new',
#  'one of worst films',
#  'might been',
#  'if want',
#  'acting horrible',
#  'movie awful',
#  'all great',
#  'wondering',
#  'at least',
#  'better than this',
#  'but even',
#  'laugh',
#  'james stewart',
#  'worst',
#  'uplifting',
#  'great characters',
#  'stick to',
#  'one dimensional',
#  'tasteless',
#  'looking',
#  'favourite',
#  'tries to',
#  'laughably',
#  'bottom of barrel',
#  'enchanting',
#  'bad film',
#  'timeless',
#  'award',
#  'poor',
#  'so stupid',
#  'how did',
#  '7 out',
#  'wanted',
#  'felt like',
#  'believe',
#  'pleasure',
#  'so bad that',
#  'not watch this',
#  'confusing',
#  'does not make',
#  'ripped',
#  'beautiful film',
#  'if really',
#  'just too',
#  'in many',
#  'just plain bad',
#  'if want to see',
#  'rest of movie',
#  'really bad',
#  'won',
#  'this piece',
#  'half way through',
#  '10 10',
#  'flat',
#  'great performance',
#  'miss this',
#  'see for',
#  'disaster',
#  'very little',
#  'sense at all',
#  'this piece of garbage',
#  'care about',
#  'really enjoyed this',
#  'even worse',
#  'scary',
#  'paul',
#  'dude',
#  'unoriginal',
#  'deeper',
#  'finest',
#  'barbara',
#  'will not regret',
#  '3',
#  'would not',
#  'not waste time on',
#  'uwe',
#  'not funny at all',
#  'fell in love with',
#  'well worth watching',
#  'or',
#  'strength',
#  'renting',
#  'this crap',
#  'not recommended',
#  'tragic',
#  'another great',
#  'funny at all',
#  'unbelievable',
#  'loving',
#  'expertly',
#  'marvelous',
#  'well written',
#  'should been',
#  'jokes',
#  'available',
#  'this by far worst',
#  'even that',
#  'do not even',
#  'not that',
#  'stay away from',
#  'thing about',
#  'cannot save',
#  'must see for',
#  'city',
#  'film works',
#  'elegant',
#  'would not recommend',
#  'on dvd',
#  '4 10',
#  'films of',
#  'wow',
#  'even',
#  'yet',
#  'real life',
#  'gore',
#  'spot on',
#  'rent',
#  'horrible movie',
#  'always been',
#  'waste money on',
#  'in many ways',
#  'not help',
#  'really liked',
#  'to life',
#  'years later',
#  'nothing to do',
#  'steals show',
#  'seemed like',
#  'movie could been',
#  'any real',
#  'been',
#  'retarded',
#  'others',
#  'piece of junk',
#  'movie sucks',
#  '4',
#  'failed miserably',
#  'had',
#  'spent on',
#  'throwing',
#  'little to',
#  'bunch',
#  '9 from outer space',
#  'do yourself favor',
#  'but also',
#  'for best',
#  'wasted in',
#  'worthless',
#  'travesty',
#  'stupidest',
#  'par',
#  'guys',
#  'one of great',
#  'boredom',
#  'had potential',
#  'made this',
#  'not even close',
#  'killed',
#  'stinks',
#  'one of best',
#  'worse',
#  'to laugh',
#  'played',
#  'awful film',
#  'sucked',
#  'atrocious',
#  'series',
#  'this terrible',
#  'for each',
#  'relate',
#  'movie do not',
#  'junk',
#  'even funny',
#  'carries',
#  'incredible',
#  'spectacular',
#  'nudity',
#  'mess',
#  'horribly',
#  'as well as',
#  'score by',
#  'sort of',
#  'crappy',
#  'whole movie',
#  'based on true story',
#  'more like',
#  'look like',
#  'mystery science',
#  'what thinking',
#  'wasted time',
#  'through this',
#  'true',
#  'relationship',
#  'to laugh at',
#  'waste time with',
#  'poorly executed',
#  'both',
#  'gave 2',
#  'chance to',
#  'who',
#  'known',
#  'or even',
#  'nothing new',
#  'impressive',
#  '1 10',
#  'of 1',
#  'of worst',
#  'time with this',
#  'highly recommend this',
#  'winning',
#  'family',
#  'touch',
#  'to live',
#  'positive',
#  'else',
#  'entire movie',
#  'must for',
#  'advice',
#  'not for everyone',
#  'very much',
#  'kill',
#  'totally',
#  'obviously',
#  ...]

# %%
top_features_df = feature_statistic_df[feature_statistic_df['feature'].isin(top_features_list)]
top_features_df = top_features_df.sort_values(by='abs_statistic', ascending=False)
top_features_df
# Out:
#                   feature  statistic  abs_statistic
# 2537                  bad -94.755462      94.755462
# 31315               worst -84.764359      84.764359
# 10874               great  73.982716      73.982716
# 29641               waste -68.997657      68.997657
# 2465                awful -64.850629      64.850629
# ...                   ...        ...            ...
# 7488         easily worst -11.236193      11.236193
# 17499  not waste money on -11.191427      11.191427
# 26432         this drivel -11.158397      11.158397
# 2544          bad as this -11.147890      11.147890
# 11822     how not to make -11.113408      11.113408
#
# [2009 rows x 3 columns]

# %% [markdown]
# ### Lasso Regression to find the Top ~1000 Tokens

# %%
top_features_df['feature']
# Out:
# 2537                    bad
# 31315                 worst
# 10874                 great
# 29641                 waste
# 2465                  awful
#                 ...
# 7488           easily worst
# 17499    not waste money on
# 26432           this drivel
# 2544            bad as this
# 11822       how not to make
# Name: feature, Length: 2009, dtype: object

# %%
# Vectorize all training data using the 2009 most significant ngrams

custom_vectorizer = CountVectorizer(
    vocabulary=top_features_df['feature'], # The top 2009 features
    stop_words=stopwords,                  # Remove stop words
    ngram_range=(1, 4),                    # Use 1- to 4-grams
    min_df=0.001,                          # Minimum term frequency
    max_df=0.5,                            # Maximum document frequency
    token_pattern=r"\b[\w+\|']+\b"         # Use word tokenizer, but don't split on apostrophes
)

X_train = custom_vectorizer.fit_transform(all_train['review'])  # all_train reviews have already been preprocessed
Y_train = all_train['sentiment']

# %%
def find_best_tokens(num, c):
    """
    Find a Lasso regularization setting to give us the 1000 most significant tokens
    out of the 2009 above.
    """
    for i in range(1000):
        lasso_log_model = LogisticRegression(C=c, penalty='l1', solver='liblinear', max_iter=100000)  # very high max iter to ensure converge
        #X_train = custom_vectorizer.fit_transform(preprocess_reviews(all_train['review']))
        #Y_train = all_train['sentiment']
        lasso_log_model.fit(X_train, Y_train)

        best_tokens = [[i, coef] for i, coef in enumerate(lasso_log_model.coef_[0]) if coef != 0]

        num_tokens = len(best_tokens)
        print(f'number of tokens: {num_tokens}')
        print(f'old c: {c}')
        
        diff = num_tokens-num

        if num_tokens == num:
            return best_tokens
        elif num_tokens > num:
            c = c*.999
        elif num_tokens < num:
            c = c*1.001

        print(f'new c: {c}')
    print("Bad initial c value, try another value")
    raise Exception

# %%
# Find a Lasso regularization parameter setting that gives us exactly 1000 ngrams.

best_tokens = find_best_tokens(num=1000, c=0.04604)
# Out:
# number of tokens: 1001
# old c: 0.04604
# new c: 0.04599396
# number of tokens: 1001
# old c: 0.04599396
# new c: 0.04594796604
# number of tokens: 1003
# old c: 0.04594796604
# new c: 0.04590201807396
# number of tokens: 1002
# old c: 0.04590201807396
# new c: 0.04585611605588604
# number of tokens: 998
# old c: 0.04585611605588604
# new c: 0.045901972171941925
# number of tokens: 1002
# old c: 0.045901972171941925
# new c: 0.045856070199769984
# number of tokens: 1002
# old c: 0.045856070199769984
# new c: 0.04581021412957021
# number of tokens: 999
# old c: 0.04581021412957021
# new c: 0.04585602434369978
# number of tokens: 1002
# old c: 0.04585602434369978
# new c: 0.04581016831935608
# number of tokens: 998
# old c: 0.04581016831935608
# new c: 0.04585597848767543
# number of tokens: 1002
# old c: 0.04585597848767543
# new c: 0.045810122509187756
# number of tokens: 998
# old c: 0.045810122509187756
# new c: 0.04585593263169694
# number of tokens: 1001
# old c: 0.04585593263169694
# new c: 0.04581007669906524
# number of tokens: 998
# old c: 0.04581007669906524
# new c: 0.0458558867757643
# number of tokens: 1002
# old c: 0.0458558867757643
# new c: 0.04581003088898854
# number of tokens: 998
# old c: 0.04581003088898854
# new c: 0.04585584091987752
# number of tokens: 1001
# old c: 0.04585584091987752
# new c: 0.045809985078957643
# number of tokens: 1004
# old c: 0.045809985078957643
# new c: 0.04576417509387869
# number of tokens: 1000
# old c: 0.04576417509387869

# %%
# Display the top 1000 ngrams, sorted by descending model coefficient values

top_features_df = pd.DataFrame(top_features.items(), columns=['token', 'feature'])
best_tokens_df = pd.DataFrame(best_tokens, columns=['index', 'value']).set_index('index')


lasso_best_tokens_df = top_features_df.join(best_tokens_df)
lasso_best_tokens_df = lasso_best_tokens_df.dropna()
lasso_best_tokens_df['weight'] = lasso_best_tokens_df['value'].abs()

lasso_best_tokens_df = lasso_best_tokens_df.sort_values(by='weight', ascending=False)
lasso_best_tokens_df
# Out:
#       token      feature     value    weight
# 158     289         7 10  2.702648  2.702648
# 180     244         4 10 -2.301557  2.301557
# 170     215         3 10 -2.148313  2.148313
# 117     301         8 10  1.695134  1.695134
# 435     223  3 out of 10 -1.684497  1.684497
# ...     ...          ...       ...       ...
# 1030  22034     riveting  0.000804  0.000804
# 575   11416         hell  0.000704  0.000704
# 1909  16975          nor -0.000506  0.000506
# 602   15114          man  0.000456  0.000456
# 38     6864           do  0.000205  0.000205
#
# [1000 rows x 4 columns]

# %%
top_features = lasso_best_tokens_df['feature'].tolist()

# %%
top_features
# Out:
# ['7 10',
#  '4 10',
#  '3 10',
#  '8 10',
#  '3 out of 10',
#  '4 out of 10',
#  'not recommend',
#  'well worth',
#  '7 out',
#  'waste',
#  'mst3k',
#  'definitely worth',
#  'refreshing',
#  'disappointment',
#  'poorly',
#  'worst',
#  '10 10',
#  'awful',
#  'not funny',
#  'unfunny',
#  '2 10',
#  'redeeming',
#  'miscast',
#  'forgettable',
#  'dull',
#  'not worth',
#  'must see',
#  'very disappointed',
#  'tedious',
#  'just not',
#  'laughable',
#  'wooden',
#  '9 10',
#  'gem',
#  'enjoyed this',
#  'disappointing',
#  'lousy',
#  'fails',
#  'wonderfully',
#  'pretentious',
#  'wasting',
#  'funniest',
#  'superb',
#  'fast forward',
#  'mildly',
#  'lacks',
#  'excellent',
#  'mediocre',
#  'appalling',
#  'olds',
#  'stinker',
#  'uninteresting',
#  'brilliantly',
#  'yawn',
#  '1 10',
#  'not very',
#  'very funny',
#  'incoherent',
#  'dreadful',
#  'hilarious',
#  'terrible',
#  'no sense',
#  'loved this',
#  'unwatchable',
#  'pointless',
#  'trite',
#  'bland',
#  'boring',
#  'amazing',
#  'embarrassing',
#  'tiresome',
#  'pathetic',
#  'perfect',
#  'below average',
#  'solid',
#  'fantastic',
#  'lame',
#  'to recommend',
#  'this great',
#  '7',
#  'worse',
#  'pleasantly surprised',
#  'weak',
#  'ridiculous',
#  'for everyone',
#  'avoid',
#  'stock footage',
#  'horrible',
#  'finest',
#  'avoid this',
#  'mystery science',
#  'first rate',
#  'credibility',
#  'love this',
#  'would love to',
#  'only good',
#  'incredible',
#  'wanted to like',
#  '8',
#  'outstanding',
#  'just did',
#  'painful',
#  'noir',
#  'mess',
#  'uninspired',
#  'wonderful',
#  'poor',
#  'annoying',
#  'favorite',
#  'enjoyable',
#  'wasted',
#  'amateurish',
#  'subtle',
#  'hoping',
#  'endless',
#  'top notch',
#  'of best',
#  'cheap',
#  'not good',
#  'badly',
#  'underrated',
#  'perfectly',
#  'am afraid',
#  'what makes',
#  'first saw',
#  '1 out',
#  'worst movie',
#  'brilliant',
#  'liked this',
#  'highly recommended',
#  'rubbish',
#  'sorry',
#  'beautifully',
#  'this thing',
#  'shallow',
#  'surprisingly',
#  'supposedly',
#  'grade d',
#  'save',
#  'unforgettable',
#  'not enough to',
#  'paint',
#  'cannot wait',
#  'awesome',
#  'sadly',
#  'freedom',
#  'believable',
#  '8 out',
#  'today',
#  'instead',
#  'favourite',
#  'of seat',
#  'surprised',
#  'of fun',
#  'way too',
#  'extraordinary',
#  'powerful',
#  'nevertheless',
#  'sucks',
#  'not even',
#  '10 out',
#  'unconvincing',
#  'entertaining',
#  'unfortunately',
#  'treat',
#  'skip this',
#  'dimensional',
#  'walked',
#  'of worst',
#  'stay away',
#  'not help',
#  'this piece of',
#  'delightful',
#  'simply not',
#  'will not be disappointed',
#  'exceptional',
#  'rare',
#  'highly recommend',
#  'predictable',
#  'turkey',
#  'recommended',
#  'be seen',
#  'unless',
#  'bore',
#  'drivel',
#  'eerie',
#  'neither',
#  'thought provoking',
#  'garbage',
#  'ashamed',
#  'great',
#  'just right',
#  'not recommended',
#  'unexpected',
#  'at best',
#  'impressed',
#  'cardboard',
#  'chilling',
#  'captures',
#  'satisfying',
#  'than this',
#  'unintentional',
#  'realistic',
#  'attempt at',
#  '2 out',
#  'very good',
#  'failed',
#  'hype',
#  'loved',
#  'embarrassed',
#  'ruined',
#  'stupid',
#  'pleasure',
#  'lacking',
#  'touching',
#  'first time',
#  'may not',
#  'writers',
#  'based on true story',
#  'thanks',
#  'sweet',
#  'crap',
#  'intense',
#  'none of',
#  'insult',
#  'interesting but',
#  'might been',
#  'outer space',
#  'at first',
#  '8 out of',
#  'masterpiece',
#  '7 out of',
#  'promising',
#  'how bad',
#  'appreciated',
#  'felt like',
#  'look like',
#  'cliché',
#  'confusing',
#  'boredom',
#  'definitely',
#  'worth seeing',
#  'barely',
#  'fun',
#  'spectacular',
#  'inappropriate',
#  'nothing',
#  'surreal',
#  'hooked',
#  'does not make',
#  'watch again',
#  '4',
#  'bored',
#  'two hours',
#  'unbelievable',
#  'enjoyed',
#  'of war',
#  'fascinating',
#  'had high',
#  'at all',
#  'stunning',
#  'so bad',
#  'if want',
#  'lacked',
#  'little to',
#  'what with',
#  'supposed',
#  'thin',
#  'best',
#  'to believe',
#  'watchable',
#  'little film',
#  'okay',
#  'steals',
#  'bad',
#  'one star',
#  'one of worst',
#  'warm',
#  'release',
#  'twists',
#  'not work',
#  'this crap',
#  'this mess',
#  'unintentionally',
#  'be missed',
#  'highly',
#  'below',
#  'not very good',
#  'see again',
#  'too many',
#  'simple',
#  'great job',
#  'unlike',
#  'potential',
#  'especially',
#  'consequences',
#  'remotely',
#  'terrific',
#  'atmosphere',
#  'ugly',
#  'just does',
#  'strong',
#  'liked',
#  'unlikeable',
#  'screaming',
#  'bother',
#  'horribly',
#  'fun film',
#  'easy',
#  'wonder',
#  'genius',
#  'gritty',
#  'that about',
#  'disappointed',
#  'clichés',
#  'if this',
#  'even better',
#  'script',
#  'silly',
#  'seemed',
#  'very little',
#  'should never',
#  'very well',
#  'movie just',
#  'disjointed',
#  'if had',
#  'worthless',
#  'carries',
#  'not miss',
#  'ludicrous',
#  'available',
#  'tense',
#  'on dvd',
#  'par',
#  'nicely',
#  'not much',
#  'delivers',
#  'moving',
#  'emotions',
#  'oh',
#  'what point',
#  'effective',
#  'as if',
#  'hated',
#  'instead of',
#  'positive',
#  'not one',
#  'this best',
#  'inaccurate',
#  'basically',
#  'turd',
#  'unique',
#  'innocent',
#  'touches',
#  'not watch this',
#  'enjoy',
#  'impact',
#  'could been',
#  'human',
#  'recommend',
#  'sake',
#  'absolutely no',
#  'on edge of',
#  'through this',
#  'to all',
#  'disaster',
#  'bad but',
#  'would been',
#  'lifeless',
#  'surprising',
#  'paid',
#  'ok',
#  'far too',
#  'idea',
#  'compelling',
#  'going for',
#  'sensitive',
#  'classic',
#  'trash',
#  'looked',
#  'do not miss',
#  'this excellent',
#  'but still',
#  'problem',
#  'thrown',
#  'terribly',
#  'beautiful',
#  'seagal',
#  'skip',
#  'makes',
#  'well done',
#  'sit through',
#  'job',
#  'cried',
#  'minutes',
#  'bit',
#  'greatest',
#  'sharp',
#  'at times',
#  'tripe',
#  'adds',
#  'am sorry',
#  'traditional',
#  'great movie',
#  'existent',
#  'chance',
#  'recommend this',
#  'only thing',
#  'absolutely nothing',
#  'quiet',
#  'appreciate',
#  'effort',
#  'witty',
#  'still',
#  'do not believe',
#  'camera',
#  'boll',
#  'honestly',
#  'genuine',
#  'ages',
#  'saw this',
#  'otherwise',
#  'some kind of',
#  'downhill',
#  'so called',
#  'edge',
#  'guess',
#  'tells',
#  'matthau',
#  'paced',
#  'did this',
#  'different',
#  'very bad',
#  'film very',
#  'just plain',
#  'very entertaining',
#  'tears',
#  'flat',
#  'performance as',
#  'apparently',
#  'beauty',
#  '1',
#  'repetitive',
#  'well written',
#  '10 out of',
#  'whatsoever',
#  'marvelous',
#  'sometimes',
#  'thumbs up',
#  'haunting',
#  'no story',
#  'lack of',
#  'paper',
#  'follows',
#  'experience',
#  'original',
#  'ed wood',
#  'impressive',
#  'in lives',
#  'money',
#  'without any',
#  'movie great',
#  'good as',
#  'tries to be',
#  'rented',
#  '9',
#  'ways',
#  'want to see',
#  'of most',
#  'or something',
#  'really bad',
#  'any of',
#  'someone',
#  'future',
#  'idiotic',
#  'that would',
#  'crappy',
#  'clichéd',
#  'at same',
#  'filmmakers',
#  'attempt to',
#  'be comedy',
#  'courage',
#  'not believe',
#  'waste of',
#  'trying',
#  'performances',
#  'own',
#  'not enough',
#  'unrealistic',
#  'nonsense',
#  'for anyone who',
#  'minutes of',
#  'tasteless',
#  'at time',
#  'grade',
#  'season',
#  'joke',
#  'remarkable',
#  'relationship',
#  'care about',
#  'looks',
#  'going to',
#  'comedies',
#  'lazy',
#  'accent',
#  'random',
#  'work of',
#  'not that',
#  'looking',
#  'gives',
#  'absurd',
#  'moved',
#  'episodes',
#  'writing',
#  'superbly',
#  'scientist',
#  'frank',
#  'b movie',
#  'muddled',
#  'suppose',
#  'embarrassment',
#  'wrong',
#  'attempt',
#  'around in',
#  'least',
#  'why',
#  'portrayal',
#  'louis',
#  'brutal',
#  'bunch of',
#  'this just',
#  'complex',
#  'friendship',
#  'this piece',
#  'flawless',
#  'seconds',
#  'both',
#  'spot on',
#  'shows',
#  'always',
#  'memorable',
#  'anything',
#  'rip off of',
#  'dvd',
#  'light',
#  'one of best',
#  'not seen',
#  'zombies',
#  'raw',
#  'reason',
#  'except',
#  'dream',
#  'for those',
#  'excuse',
#  'producers',
#  '2 out of 10',
#  'save this',
#  'must for',
#  'minutes into',
#  'tale',
#  'brings',
#  'atrocious',
#  'just too',
#  'either',
#  'sees',
#  'f',
#  'true',
#  'advice',
#  'utter',
#  'black white',
#  'story of',
#  'come on',
#  'works',
#  'of this movie',
#  'familiar',
#  'failure',
#  'sort',
#  'bin',
#  'continuity',
#  'to find',
#  'but no',
#  'recommend to',
#  'episode',
#  'nowhere',
#  'gorgeous',
#  'although',
#  'for this',
#  'keeps',
#  'reality',
#  'premise',
#  'stick',
#  'useless',
#  'gore',
#  'feelings',
#  'fabulous',
#  'blah',
#  'all time',
#  'bad movie',
#  'ripped',
#  'later',
#  'dumb',
#  'half',
#  'love',
#  'to make',
#  'much better',
#  'rip off',
#  'alright',
#  'often',
#  'plot',
#  'entire',
#  'write',
#  'world',
#  'completely',
#  'charming',
#  'junk',
#  'heart',
#  'jean',
#  'bottom of',
#  'low',
#  'more like',
#  'strength',
#  'story told',
#  '3',
#  'yet',
#  'be good',
#  'actors',
#  'see',
#  'truly',
#  'barbara',
#  'this one of',
#  'should been',
#  'bad movies',
#  'together',
#  'even that',
#  'no idea',
#  'on on',
#  'life',
#  'project',
#  'film just',
#  'shelf',
#  'saving grace',
#  'dialogue',
#  'wretched',
#  'series',
#  'piece of',
#  'insulting',
#  'cannot believe',
#  'well',
#  'want to',
#  'others',
#  'sense of',
#  'journey',
#  'brought',
#  'thoroughly',
#  'overlooked',
#  'cannot',
#  'if really',
#  'also',
#  'incomprehensible',
#  'ever',
#  'as good',
#  'obnoxious',
#  'each',
#  'inept',
#  'quite',
#  'romantic',
#  'small',
#  'for first time',
#  'killed',
#  'seems',
#  'may not be',
#  'kills',
#  'music',
#  'no',
#  'nudity',
#  '90',
#  'made this',
#  'plus side',
#  '10 minutes',
#  'one of greatest',
#  'say about',
#  'power of',
#  'bit too',
#  'delight',
#  'dire',
#  'thing about',
#  'this very',
#  'want',
#  'pretty bad',
#  'sequel',
#  'doing',
#  'soundtrack',
#  'french',
#  'that will',
#  'some good',
#  'other than',
#  'late',
#  'city',
#  'complete',
#  'acting',
#  'only',
#  'gripping',
#  'shoot',
#  'but this',
#  'to act',
#  'cash in',
#  'played',
#  'looks like',
#  'joy',
#  'not watch',
#  'will',
#  'may',
#  'takes',
#  'bad this',
#  'adds to',
#  'become',
#  'timeless',
#  'great film',
#  'with this',
#  'oscar',
#  'obvious',
#  'asleep',
#  'please',
#  'would',
#  'effects',
#  'very',
#  'nature',
#  'favorites',
#  'plastic',
#  'would recommend',
#  'mature',
#  'miss',
#  'for first',
#  'certainly',
#  'years',
#  'god',
#  'lives',
#  'themes',
#  'off',
#  'most',
#  'decent',
#  'fast paced',
#  '2',
#  'reason to',
#  'dialog',
#  'should',
#  'tries',
#  'irritating',
#  'with no',
#  'cover',
#  'blood',
#  'like watching',
#  '9 out of',
#  'dreams',
#  'splendid',
#  'might',
#  'make movie',
#  'maybe',
#  'why do',
#  'sex',
#  'sucked',
#  'helps',
#  'about as',
#  'obviously',
#  'could not',
#  'in love',
#  'day',
#  'what thinking',
#  'strongly',
#  'no real',
#  'society',
#  'as good as',
#  'disgusting',
#  'stock',
#  'get',
#  'straight',
#  'magnificent',
#  'bothered',
#  'really',
#  'in this movie',
#  'inspiring',
#  'released',
#  'new',
#  'guys',
#  'in opinion',
#  'cast',
#  'home',
#  'played by',
#  'best film',
#  'out',
#  'perfection',
#  'in movie',
#  'to sit through',
#  'feel good',
#  'rent',
#  'care',
#  'happiness',
#  'to be',
#  'many',
#  'happy',
#  'mean',
#  'fine',
#  'looked like',
#  'see for',
#  'finds',
#  'only complaint',
#  'killer',
#  'hackneyed',
#  'images',
#  'very much',
#  'any',
#  'budget',
#  'even',
#  'movie ever',
#  'did not',
#  'great acting',
#  'watching',
#  'whole',
#  'one of',
#  'provides',
#  'of crap',
#  'everyday',
#  "today's",
#  'bad film',
#  'nothing to',
#  'times',
#  'family',
#  'on this',
#  'notch',
#  'viewing',
#  'jokes',
#  'film for',
#  'could',
#  'with great',
#  'makers',
#  'on plus side',
#  'even close to',
#  'pitiful',
#  'story about',
#  'believe that',
#  'hour',
#  'real',
#  'spent on',
#  'better',
#  'laugh',
#  'horrid',
#  'this movie had',
#  'shots',
#  'unnecessary',
#  'bunch',
#  'performances of',
#  'enough',
#  'vhs',
#  'would be',
#  'watching this',
#  'to do',
#  'something',
#  'there not',
#  'can relate',
#  'moments',
#  'if want to',
#  'does not',
#  'touched',
#  'one of most',
#  'to write',
#  'like',
#  'for all',
#  'stewart',
#  'creature',
#  'fresh',
#  'worst movies',
#  'monster',
#  'performance',
#  'rest',
#  'say',
#  'only reason',
#  'cgi',
#  'history',
#  'on this one',
#  'problem with',
#  'of movie',
#  'for best',
#  'out of',
#  'contrast',
#  'so',
#  'if',
#  'stands',
#  'tremendous',
#  'excellently',
#  'kill',
#  'young',
#  'drags',
#  'this movie',
#  'whole movie',
#  'hours',
#  'spent',
#  'who',
#  'in first',
#  'made',
#  'believe',
#  'wow',
#  'problem that',
#  'movies',
#  'of original',
#  'but even',
#  'visual',
#  'did',
#  'throwing',
#  'stupidity',
#  'films',
#  'of own',
#  'important',
#  'lines',
#  'else',
#  '9 out of 10',
#  'as well',
#  'war',
#  'guy',
#  'film school',
#  'deeper',
#  'be funny',
#  'that this',
#  'married',
#  'david',
#  'lovely',
#  'age',
#  'decided to',
#  'contrived',
#  'do not',
#  'been better',
#  'rest of movie',
#  'somebody',
#  'live',
#  'point',
#  'horror',
#  'performances by',
#  'john',
#  'really liked',
#  'make',
#  'wanted to',
#  'been',
#  'explained',
#  'movie no',
#  'give',
#  'editing',
#  'holds',
#  'just',
#  'emotional',
#  'then',
#  'running',
#  'lack',
#  'any real',
#  'bottom',
#  'am not',
#  'as well as',
#  'memories',
#  'by',
#  'horror movie',
#  'joy to',
#  'but just',
#  'of young',
#  'video',
#  'movie do',
#  'too bad',
#  'movie could',
#  'bothered to',
#  'for free',
#  'wondering',
#  'total',
#  'trying to be',
#  'story',
#  'cinema',
#  'because',
#  'too',
#  'award',
#  'romance',
#  'those who',
#  'to do with',
#  'well acted',
#  'tragedy',
#  'modern',
#  'hours of',
#  'of human',
#  'cheesy',
#  'roles',
#  'insult to',
#  'actually',
#  'score',
#  'saying',
#  '0',
#  'would not',
#  'retarded',
#  'role',
#  'costs',
#  'riveting',
#  'hell',
#  'nor',
#  'man',
#  'do']

# %%
# Export the top 1000 ngrams to myvocab.txt

np.savetxt("myvocab.txt", top_features, fmt="%s", delimiter=",")

# %% [markdown]
# ## 3) Find best ridge-regression model parameters for further prediction

# %%
# Vectorize the full training set using the top 1000 ngrams

top_feature_vectorizer = CountVectorizer(
    vocabulary=top_features,          # The top 1000 ngrams
    stop_words=stopwords,             # Remove stop words
    ngram_range=(1, 4),               # Use 1- to 4-grams
    min_df=0.001,                     # Minimum term frequency
    max_df=0.5,                       # Maximum document frequency
    token_pattern=r"\b[\w+\|']+\b"    # Use word tokenizer, but don't split on apostrophes
)

dtm_vocab_train = top_feature_vectorizer.fit_transform(all_train["review"])

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
grid_search = LogisticRegressionCV(Cs=10, cv=5, penalty="l2", scoring="roc_auc", max_iter=100000, random_state=SEED)

# %%
all_train_y = all_train["sentiment"]

# %%
grid_search.fit(dtm_vocab_train, all_train_y)
# Out:
# LogisticRegressionCV(cv=5, max_iter=100000, random_state=4031,
#                      scoring='roc_auc')

# %%
best_C = grid_search.C_[0]
best_C   # best_C is 21.54434690031882
# Out:
# 21.54434690031882

# %% [markdown]
# ## 4) Inference
#
# Use ```best_C``` above to train and run predictions on each of the five splits. All predictions should give AUC > 0.96.

# %%
from sklearn.metrics import roc_auc_score
import time

# %%
# Compute area under the ROC curve (AUC) for each of the five training/test splits.

auc_scores = []

for i in range(len(train_datasets)):
    start_time = time.time()
    model = LogisticRegression(C=best_C, penalty="l2", max_iter=100000, random_state=SEED)
    
    train_X = top_feature_vectorizer.fit_transform(preprocess_reviews(train_datasets[i]["review"]))
    train_y = train_datasets[i]["sentiment"]
    
    model.fit(train_X, train_y)
    
    test_X = top_feature_vectorizer.transform(preprocess_reviews(test_datasets[i]["review"]))
    test_y = test_ys[i]["sentiment"]
    
    pred_y = model.predict_proba(test_X)[:, 1]  # Predict probabilities for class 1 (positive review)
    
    auc_score = roc_auc_score(test_y, pred_y)
    auc_scores.append(auc_score)
    
    print(f"AUC of split {i+1}: {auc_score}")
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Split {i+1} run time: {elapsed_time} seconds")
# Out:
# AUC of split 1: 0.9616726083797218
# Split 1 run time: 186.57749891281128 seconds
# AUC of split 2: 0.9616009217810427
# Split 2 run time: 187.39333772659302 seconds
# AUC of split 3: 0.9610771609287114
# Split 3 run time: 187.07028603553772 seconds
# AUC of split 4: 0.9621485005750404
# Split 4 run time: 191.3993124961853 seconds
# AUC of split 5: 0.96203883948773
# Split 5 run time: 187.2207088470459 seconds
